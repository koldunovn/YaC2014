# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pylab as plt

import seaborn as sns
sns.set_context('poster',rc ={"figure.figsize": [10,5.5]})

# %%
temp = pd.read_csv('cptls.txt', index_col='Time', parse_dates=True)

# %%
temp.head()
# Out:
#              Msk   SpB
# Time
# 1948-01-31  -7.8  -7.7
# 1948-02-29 -10.7  -9.6
# 1948-03-31  -4.4  -3.9
# 1948-04-30   5.9   4.0
# 1948-05-31  15.3  12.7

# %%
type(temp)
# Out:
# pandas.core.frame.DataFrame

# %%
temp.plot()

# %%
temp['2011':'2013']
# Out:
#              Msk   SpB
# Time
# 2011-01-31  -7.5  -5.8
# 2011-02-28 -11.0 -11.0
# 2011-03-31  -2.0  -1.9
# 2011-04-30   6.4   5.7
# 2011-05-31  14.6  11.0
# 2011-06-30  19.0  17.7
# 2011-07-31  23.4  22.5
# 2011-08-31  18.7  17.5
# 2011-09-30  12.1  13.1
# 2011-10-31   6.6   7.6
# 2011-11-30   0.2   3.6
# 2011-12-31  -0.1   1.9
# 2012-01-31  -6.8  -4.8
# 2012-02-29 -11.7 -10.4
# 2012-03-31  -3.1  -1.0
# 2012-04-30   8.2   4.9
# 2012-05-31  15.1  12.7
# 2012-06-30  17.1  15.2
# 2012-07-31  20.9  19.5
# 2012-08-31  17.7  16.3
# 2012-09-30  12.9  12.9
# 2012-10-31   6.5   6.6
# 2012-11-30   1.6   2.9
# 2012-12-31  -8.6  -7.9
# 2013-01-31  -8.5  -6.1
# 2013-02-28  -3.5  -2.6
# 2013-03-31  -6.5  -6.6
# 2013-04-30   6.1   4.2
# 2013-05-31  16.9  14.4
# 2013-06-30  19.8  19.8
# 2013-07-31  18.9  19.0
# 2013-08-31  18.3  18.6
# 2013-09-30  10.3  12.1
# 2013-10-31   6.6   7.3
# 2013-11-30   NaN   NaN
# 2013-12-31   NaN   NaN

# %%
temp['2011':'2013'].plot()

# %%
temp['2011-12':'2013-05'].plot()

# %%
temp.head()
# Out:
#              Msk   SpB
# Time
# 1948-01-31  -7.8  -7.7
# 1948-02-29 -10.7  -9.6
# 1948-03-31  -4.4  -3.9
# 1948-04-30   5.9   4.0
# 1948-05-31  15.3  12.7

# %%
temp.SpB.plot()

# %%
temp['SpB'].plot()

# %% [markdown]
# Select months when temperature in St. Petersburg was larger than 0.

# %%
temp[temp.SpB>0].plot(style='*')

# %%
temp.SpB>0
# Out:
# Time
# 1948-01-31    False
# 1948-02-29    False
# 1948-03-31    False
# 1948-04-30     True
# 1948-05-31     True
# 1948-06-30     True
# 1948-07-31     True
# 1948-08-31     True
# 1948-09-30     True
# 1948-10-31     True
# 1948-11-30     True
# 1948-12-31    False
# 1949-01-31    False
# 1949-02-28    False
# 1949-03-31    False
# 1949-04-30     True
# 1949-05-31     True
# 1949-06-30     True
# 1949-07-31     True
# 1949-08-31     True
# 1949-09-30     True
# 1949-10-31     True
# 1949-11-30     True
# 1949-12-31    False
# 1950-01-31    False
# 1950-02-28    False
# 1950-03-31    False
# 1950-04-30     True
# 1950-05-31     True
# 1950-06-30     True
#               ...
# 2011-07-31     True
# 2011-08-31     True
# 2011-09-30     True
# 2011-10-31     True
# 2011-11-30     True
# 2011-12-31     True
# 2012-01-31    False
# 2012-02-29    False
# 2012-03-31    False
# 2012-04-30     True
# 2012-05-31     True
# 2012-06-30     True
# 2012-07-31     True
# 2012-08-31     True
# ...

# %% [markdown]
# Select months when temperature in Moscow was larger than 0 and show temperature in St. Petersburg for this months.

# %%
temp.SpB[temp.Msk>0].plot(style='*')

# %% [markdown]
# Select points, when temperature in Moscow was larger than 0 and in St. Petersburg lower than 0. Then show only data for St. Petersburg:

# %%
temp.SpB[(temp.Msk>0)&(temp.SpB<0)].plot(style='*')

# %% [markdown]
# Same, but the other way round.

# %%
temp.SpB[(temp.Msk<0)&(temp.SpB>0)].plot(style='*')
