# %% [markdown]
# # Using Python for interactive data analysis

# %% [markdown]
# Nikolay Koldunov
#
# koldunovn@gmail.com

# %% [markdown]
# ## Interactive programming

# %% [markdown]
# - In the beggining of the day we don't know what we are going to write.
# - Code should be as short as possible
# - Easy visualization of the results
# - We have to be able to easilly reproduce our analysis

# %% [markdown]
# ## ~~Python~~ Jupyter notebook

# %% [markdown]
# - Allows to work with text, code and visualization in the same time.
# - Works in a browser (OS that everyone have)

# %% [markdown]
# ### Code execution (code cell)

# %%
print('Hi, Hamburg Python Meetup 2014')
# Out:
# Hi, Hamburg Python Meetup 2014

# %% [markdown]
# ### Text (text cell)

# %% [markdown]
# IPython [Official webpage](http://ipython.org/).
#
# List:
#
# * [Collection of interesting notebooks](https://github.com/IPython/IPython/wiki/A-gallery-of-interesting-IPython-Notebooks)
# * [IPython Notebook description](http://ipython.org/notebook.html)
#
# Syntax highlighting:
#
#     print('hello world')

# %% [markdown]
# ### Visualization

# %% [markdown]
# In order to have you graphics inside the notebook you have to import matplotlib graphics library and indicate, that your figures will be inline.

# %%
import matplotlib.pylab as plt
# %matplotlib inline

# %%
x = [1,2,3,4,5]
plt.plot(x)

# %% [markdown]
# ## Running the notebook

# %% [markdown]
# ipython notebook

# %% [markdown]
# ### Shortcuts

# %% [markdown]
# Enter       - Edit mode
#
# Escape      - Command mode
#
# Shift-Enter - run cell, select below
#
# a           - add cell **a**bove
#
# b           - add cell **b**elow
